# %% [markdown]
# # Introduction to data visualization using MatplotLib

# %% [markdown]
# ## Data is only as good as it’s presented.
# ### Why are visualizations important?
# * Visualizations are the easiest way to analyze and absorb information.
# * Visuals help to easily understand the complex problem.
# * They help in identifying patterns, relationships, and outliers in data.
# * It helps in understanding business problems better and quickly.
# * It helps to build a compelling story based on visuals.
# * Insights gathered from the visuals help in building strategies for businesses.
# * It is also a precursor to many high-level data analysis for Exploratory Data Analysis(EDA) and Machine Learning(ML).

# %% [markdown]
# ## Matplotlib
# * Matplotlib is a 2-D plotting library that helps in visualizing figures.
# * Matplotlib emulates Matlab like graphs and visualizations.
# * Matlab is not free, is difficult to scale and as a programming language is tedious.
# * So, matplotlib in Python is used as it is a robust, free and easy library for data visualization.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Installing Matplotlib
# * `!pip install matplotlib` in the Jupyter Notebook or
# * cmd type conda install `-c conda-forge matplotlib`
# * `import matplotlib.pyplot as plt` for making it call the package module

# %% [markdown]
# ## Pandas Recall and Matplotlib basics
# * Importing required libraries using Pandas `pd.read_csv()`
# * Extracting important parts for plots using conditions on Pandas Dataframes.
# * `plt.plot()`for plotting line chart similarly in place of plot other functions are used for plotting.
# * `plot.xlabel` , `plt.ylabel` for labeling x and y-axis respectively.
# * `plt.xticks` , `plt.yticks` for labeling x and y-axis observation tick points respectively.
# * `plt.legend()` for signifying the observation variables.
# * `plt.title()` for setting the title of the plot.
# * `plot.show()` for displaying the plot.

# %% [markdown]
# ### Here you will learn:
# * 1.Histogram
# * 2.Piechart
# * 3.Line Chart
# * 4.Box plot
# * 5.Twin axis
# * 6.Stack plot
# * 7.Bar plot
# * 8.Scatter plot

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1 Histogram : We should use histogram when we need the count of the variable in a plot.

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#national park not numpy
np_data=pd.read_csv('national_parks.csv')

# %%
np_data.head()
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961    833300      1253000       264800
# 1  1962   1044800      1447400       251000
# 2  1963   1074000      1539500       289500
# 3  1964   1079800      1576600       300300
# 4  1965   1091300      1689200       366800

# %%
np_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         57 non-null     int64
#  1   Badlands     57 non-null     int64
#  2   GrandCanyon  57 non-null     int64
#  3   BryceCanyon  57 non-null     int64
# dtypes: int64(4)
# memory usage: 1.9 KB

# %%
plt.hist(np_data['GrandCanyon'], facecolor='lightgreen', bins=10, edgecolor='blue')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Components of a histogram
# * <b>n:</b> Contains the frequency of each bin
# * <b>bins:</b> Represents the middle value of each bin
# * <b>patches:</b> The Patch object for the rectangle shape representing each bar

# %%
n, bins, patches= plt.hist(np_data['GrandCanyon'], 
                           facecolor='lightgreen', 
                           bins=10, 
                           edgecolor='blue')
print('n: ', n)
print('bins: ', bins)
print('patches: ', patches)
# Out:
# n:  [ 5.  9. 10.  2.  1.  9. 16.  2.  1.  2.]
# bins:  [1253000.  1753123.8 2253247.6 2753371.4 3253495.2 3753619.  4253742.8
#  4753866.6 5253990.4 5754114.2 6254238. ]
# patches:  <BarContainer object of 10 artists>

# %% [markdown]
# #### The cumulative property
# If True, then a histogram is computed where each bin gives the counts in that bin plus all bins for smaller values. The last bin gives the total number of datapoints.

# %%
plt.hist(np_data['GrandCanyon'], 
        facecolor='peru', 
        bins=10, 
        edgecolor='blue',
        cumulative=True)
plt.show()

# %% [markdown]
# #### Check the histogram to a range of values
# We only look at the data points within the range 2M-5M. This realigns the bins in the histogram

# %%
plt.hist(np_data['GrandCanyon'], 
        facecolor='peru', 
        bins=10, 
        edgecolor='blue',
        range=(2000000,5000000))
plt.show()

# %% [markdown]
# ## Multiple Histogram

# %%
plt.hist(np_data['GrandCanyon'], 
        facecolor='peru', 
        bins=10, 
        edgecolor='blue',
        alpha=0.3)
plt.hist(np_data['BryceCanyon'], 
        facecolor='orangered',
        edgecolor='maroon',
        bins=10)
plt.show()

# %% [markdown]
# ## 2  Pie Chart: Pie chart shows distribution of data based on proportion of pie occupied.

# %% [markdown]
# #### Importing Libraries and Data

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

movie_data=pd.read_csv('types_movies.csv')

# %%
movie_data.head()
# Out:
#     Sector  Percentage
# 0   Sci-Fi          20
# 1    Drama          35
# 2   Action          25
# 3   Comedy           5
# 4  Romance          15

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sector      5 non-null      object
#  1   Percentage  5 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 208.0+ bytes

# %%
plt.pie(movie_data['Percentage'],
       labels=movie_data['Sector'])
plt.axis('equal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Pie chart components
# * <b>wedges:</b> A list of Patch objects representing each wedge
# * <b>texts:</b> List of Text objects representing the labels
# * <b>autotexts:</b> List of Text objects for the numeric values - this is only availabe if the autopct value for the pie chart is not None

# %%
wedges, texts, autotexts=plt.pie(movie_data['Percentage'],
                                labels=movie_data['Sector'],
                                autopct='%.1f')
plt.axis('equal')
print('wedges: ', wedges)
print('texts: ', texts)
print('autotexts: ', autotexts)
# Out:
# wedges:  [<matplotlib.patches.Wedge object at 0x7fe8f805fd30>, <matplotlib.patches.Wedge object at 0x7fe92baee790>, <matplotlib.patches.Wedge object at 0x7fe92baeee80>, <matplotlib.patches.Wedge object at 0x7fe8f804d610>, <matplotlib.patches.Wedge object at 0x7fe8f804dd30>]
# texts:  [Text(0.8899186877588753, 0.6465637858537406, 'Sci-Fi'), Text(-0.7778174593052023, 0.7778174593052024, 'Drama'), Text(-0.49938956806635254, -0.9801071672559599, 'Action'), Text(0.4993895336547568, -0.9801071847895437, 'Comedy'), Text(0.9801071789450159, -0.49938954512528877, 'Romance')]
# autotexts:  [Text(0.4854101933230228, 0.35267115592022213, '20.0'), Text(-0.42426406871192845, 0.4242640687119285, '35.0'), Text(-0.2723943098543741, -0.5346039094123417, '25.0'), Text(0.27239429108441277, -0.5346039189761147, '5.0'), Text(0.5346039157881904, -0.27239429734106657, '15.0')]

# %% [markdown]
# #### Pie chart customizations
#  We set the values for the colors and autopct properties. The latter sets the format for the values to be displayed.

# %% [markdown]
# https://matplotlib.org/stable/gallery/color/named_colors.html

# %%
colors_list=['darkorange','sandybrown','darksalmon','orangered','chocolate']

# %%
plt.pie(movie_data['Percentage'], 
        labels=movie_data['Sector'],
       colors=colors_list, 
       autopct='%.2f')
plt.axis('equal')
plt.show()

# %% [markdown]
# #### The explode property
# To highlight a particular wedge of the pie chart, we use explode to separate it from the rest of the chart.
#
# The value for "explode" represents the fraction of the radius with which to offset each wedge.

# %%
colors_list=['darkorange','sandybrown','darksalmon','orangered','chocolate']
explode=(0, 0.1, 0,0,0.3)

plt.pie(movie_data['Percentage'], 
        labels=movie_data['Sector'],
       colors=colors_list, 
       autopct='%.2f',
       explode=explode)
        
plt.axis('equal')
plt.show()

# %% [markdown]
# ## 3 Time Series by line plot
# * Time series is a line plot and it is basically connecting data points with a straight line.
# * It is useful in understanding the trend over time.
# * It can explain the correlation between points by the trend.
# * An upward trend means positive correlation and downward trend means a negative correlation.
# * It mostly used in forecasting, monitoring models.

# %%
stocks_data=pd.read_csv('stocks.csv')

# %%
stocks_data.head()
# Out:
#        Date       AAPL       ADBE        CVX        GOOG        IBM  \
# 0  3-Jan-07  11.107141  38.869999  50.777351  251.001007  79.242500
# 1  1-Feb-07  10.962033  39.250000  48.082939  224.949951  74.503204
# 2  1-Mar-07  12.037377  41.700001  51.900383  229.309311  75.561348
# 3  2-Apr-07  12.930043  41.560001  54.588032  235.925919  81.934280
# 4  1-May-07  15.701322  44.060001  57.598267  249.204208  85.786057
#
#         MDLZ       MSFT      NFLX       ORCL       SBUX
# 0  17.519524  24.118483  3.258571  15.696321  15.752188
# 1  16.019426  22.092464  3.218571  15.028588  13.930813
# 2  16.009354  21.857189  3.312857  16.583584  14.138198
# 3  16.924608  23.480597  3.167143  17.196436  13.984914
# 4  17.111704  24.146753  3.128572  17.726965  12.988567

# %%
stocks_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    121 non-null    object
#  1   AAPL    121 non-null    float64
#  2   ADBE    121 non-null    float64
#  3   CVX     121 non-null    float64
#  4   GOOG    121 non-null    float64
#  5   IBM     121 non-null    float64
#  6   MDLZ    121 non-null    float64
#  7   MSFT    121 non-null    float64
#  8   NFLX    121 non-null    float64
#  9   ORCL    121 non-null    float64
#  10  SBUX    121 non-null    float64
# dtypes: float64(10), object(1)
# memory usage: 10.5+ KB

# %%
stocks_data['Date']=pd.to_datetime(stocks_data['Date'])

# %% [markdown]
# ### Compare stocks side by side

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
fig=plt.figure(figsize=(10,6))
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.05,0.65,0.5,0.3])
ax1.set_title('AAPL vs IBM (inset)')

ax1.plot(stocks_data['Date'],
        stocks_data['AAPL'],
        color='green')
ax2.plot(stocks_data['Date'],
        stocks_data['IBM'],
        color='blue')
plt.show()

# %% [markdown]
# # comparing multiple stocks

# %%
fig=plt.figure(figsize=(15,7))
fig.suptitle("Stock price comparison 2007-2017", fontsize=20)

ax1=fig.add_subplot(231) #two rows three columns 1 axis
ax1.set_title('MSFT')
ax1.plot(stocks_data['Date'],
        stocks_data['MSFT'],
        color='green')
ax2=fig.add_subplot(232) 
ax2.set_title('GOOG')
ax2.plot(stocks_data['Date'],
        stocks_data['GOOG'],
        color='blue')
ax3=fig.add_subplot(233) 
ax3.set_title('SBUX')
ax3.plot(stocks_data['Date'],
        stocks_data['SBUX'],
        color='purple')
ax4=fig.add_subplot(234) 
ax4.set_title('ADBE')
ax4.plot(stocks_data['Date'],
        stocks_data['ADBE'],
        color='black')
ax5=fig.add_subplot(235) 
ax5.set_title('NFLX')
ax5.plot(stocks_data['Date'],
        stocks_data['NFLX'],
        color='Orange')
ax6=fig.add_subplot(236) 
ax6.set_title('ORCL')
ax6.plot(stocks_data['Date'],
        stocks_data['ORCL'],
        color='teal')


plt.show()

# %% [markdown]
# # https://matplotlib.org/stable/api/colors_api.html

# %% [markdown]
# ## 4 Boxplot
# Boxplot gives a nice summary of the data. It helps in understanding our distribution better.
# ![image.png](attachment:image.png)
# * The end of the box shows the upper quartile(75%)and the start of the box represents the lower quartile(25%).
# * Upper Quartile is also called 3rd quartile and similarly, Lower Quartile is also called as 1st quartile.
# * The region between lower quartile and the upper quartile is called as Inter Quartile Range(IQR) and it is used to approximate the 50% spread in the middle data(75–25=50%).

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
exam_data=pd.read_csv('exams.csv')

# %%
exam_data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group C            some high school  free/reduced
# 1  female        group C                some college  free/reduced
# 2    male        group A                 high school      standard
# 3    male        group B                some college      standard
# 4  female        group C             master's degree  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          69             61             58
# 1               completed          47             65             69
# 2                    none          66             52             53
# 3                    none          88             89             82
# 4                    none          62             82             76

# %%
exam_data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
exam_scores=exam_data[['math score', 'reading score', 'writing score']]

# %%
exam_scores.head()
# Out:
#    math score  reading score  writing score
# 0          69             61             58
# 1          47             65             69
# 2          66             52             53
# 3          88             89             82
# 4          62             82             76

# %%
exam_scores.describe()
# Out:
#        math score  reading score  writing score
# count  100.000000     100.000000     100.000000
# mean    67.150000      69.180000      67.780000
# std     12.797865      13.832607      14.874954
# min     36.000000      34.000000      33.000000
# 25%     56.000000      60.000000      57.750000
# 50%     68.000000      69.000000      68.500000
# 75%     76.000000      80.000000      77.250000
# max     95.000000      99.000000     100.000000

# %% [markdown]
# ###  Box plots

# %%
color=['blue', 'red','green']
bp=plt.boxplot(exam_scores, 
               patch_artist=True,
              notch=True)
plt.xticks([1,2,3], ['Math', 'Reading', 'Writing'])
for patch, color in zip(bp['boxes'],color):
    patch.set_facecolor(color)

plt.show()

# %% [markdown]
# ### Violin Plots
# Violin plot is a better chart than boxplot as it gives a much broader understanding of the distribution. It resembles a violin and dense areas point the more distribution of data otherwise hidden by box plots

# %%
vp=plt.violinplot(exam_scores, showmedians=True)
plt.xticks([1,2,3],['Math', 'Reading', 'Writing'])
plt.show()

# %% [markdown]
# ## TwinAxis
# * TwinAxis helps in visualizing plotting 2 plots w.r.t to the y-axis and same x-axis.
# * It should when we require 2 plots or grouped data in the same direction.

# %%
austin_weather=pd.read_csv('austin_weather.csv')

# %%
austin_weather.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
# ...

# %%
austin_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1319 non-null   int64
#  2   TempAvgF                    1319 non-null   int64
#  3   TempLowF                    1319 non-null   int64
#  4   DewPointHighF               1319 non-null   object
#  5   DewPointAvgF                1319 non-null   object
#  6   DewPointLowF                1319 non-null   object
#  7   HumidityHighPercent         1319 non-null   object
#  8   HumidityAvgPercent          1319 non-null   object
#  9   HumidityLowPercent          1319 non-null   object
#  10  SeaLevelPressureHighInches  1319 non-null   object
#  11  SeaLevelPressureAvgInches   1319 non-null   object
#  12  SeaLevelPressureLowInches   1319 non-null   object
# ...

# %% [markdown]
# #### Extracting Date,Avg Temperature and Avg Wind Speed columns

# %%
austin_weather=austin_weather[['Date', 'TempAvgF', 'WindAvgMPH']].head(30)

# %%
austin_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        30 non-null     object
#  1   TempAvgF    30 non-null     int64
#  2   WindAvgMPH  30 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 848.0+ bytes

# %% [markdown]
# ### Plotting two lines with 2 separate Y axes with the same X axis
# First create one axis and then use the twinx() function to create another axis sharing the same X axis
# ![image.png](attachment:image.png)

# %%
fig=plt.figure(figsize=(12,6))

# x axis
ax1.set_xlabel('Date')
# disable ticks, and label bottom disable x axis label
ax1.tick_params(axis='x', bottom=False, labelbottom=False)

# set left y axis
ax1.set_ylabel('Temp(F)', color='red', size='x-large')

ax1.tick_params(axis='y', labelcolor='red', labelsize='large')

ax1.plot(austin_weather['Date'], austin_weather['TempAvgF'],color='red')

#set right y axis

#twinxsets the same x axis for both plots

ax2=ax1.twinx()
ax2.set_ylabel('Average wind speed (MPH)', color='blue', size='x-large')

ax2.tick_params(axis='y', labelcolor='blue', labelsize='large')

ax2.plot(austin_weather['Date'], austin_weather['WindAvgMPH'],color='blue')

plt.show()

# %% [markdown]
# ### Twin axis for the same data
# If the same data can be expressed in different units, we can configure our axis to display both units on two axes.
# ![image.png](attachment:image.png)

# %%
austin_weather.head()
# Out:
#          Date  TempAvgF WindAvgMPH
# 0  2013-12-21        60          4
# 1  2013-12-22        48          6
# 2  2013-12-23        45          3
# 3  2013-12-24        46          4
# 4  2013-12-25        50          2

# %%
#create a function called tempFtoC

def tempFtoC(f):
    return (f-32)*5/9

# %%
fig,tempF=plt.subplots()
fig=plt.figure(figsize=(12,6))
#set x axis params
tempF.set_xlabel('Date')
tempF.tick_params(axis='x', bottom=False, labelbottom=False)

#set left y axis
tempF.set_ylabel('Temp(F)', color='red', size='x-large')
tempF.tick_params(axis='y', labelcolor='red', labelsize='large')
tempF.plot(austin_weather['Date'], austin_weather['TempAvgF'], color='green')
#set right y axis
tempC=tempF.twinx()
#ymin, ymax=tempF.get_ylim()

print('ymin', ymin)
print('ymax', ymax)
tempC.set_ylim((tempFtoC(ymin), tempFtoC(ymax)))
tempC.set_ylabel('Temp(C)', color='blue', size='x-large')
tempC.tick_params(axis='y', labelcolor='blue', labelsize='large')

plt.show()
# Out:
# ymin 27.2
# ymax 66.8

# %% [markdown]
# ## 6 Stack Plot
# * Stack plot visualizes data in stacks and shows the distribution of data over time.
# * It is used for checking multiple variable area plots in a single plot.

# %%
np_data=pd.read_csv('national_parks.csv')

# %%
np_data.head()
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961    833300      1253000       264800
# 1  1962   1044800      1447400       251000
# 2  1963   1074000      1539500       289500
# 3  1964   1079800      1576600       300300
# 4  1965   1091300      1689200       366800

# %%
x=np_data['Year']
y=np.vstack([np_data['Badlands'], 
             np_data['GrandCanyon'],
            np_data['BryceCanyon']])

# %%
labels=['Badlands', 'GrandCanyon', 'BryceCanyon']
colors=['sandybrown', 'tomato', 'skyblue']
plt.stackplot(x,y,labels=labels, colors=colors, edgecolor='black')
plt.legend(loc=2)

# %%
plt.figure(figsize=(10,7))
data_perc=np_data.divide(np_data.sum(axis=1), axis=0)
plt.stackplot(x, data_perc['Badlands'], 
              data_perc["GrandCanyon"], 
              data_perc['BryceCanyon'], 
              edgecolor='black', 
             colors=colors, 
             labels=labels)
plt.legend(loc='center left', bbox_to_anchor=(1,.05))
plt.show()

# %% [markdown]
# ## 7 Bar Plot
# * Bar Plot shows the distribution of data over several groups.
# * It is commonly confused with a histogram which only takes numerical data for plotting.
# * It helps in comparing multiple numeric values.

# %%
countries=pd.read_csv('countries.csv')

# %%
countries.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         1704 non-null   object
#  1   continent       1704 non-null   object
#  2   year            1704 non-null   int64
#  3   lifeExpectancy  1704 non-null   float64
#  4   population      1704 non-null   int64
#  5   gdpPerCapita    1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
data_2007=countries[countries['year']==2007]
data_2007.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142 entries, 11 to 1703
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         142 non-null    object
#  1   continent       142 non-null    object
#  2   year            142 non-null    int64
#  3   lifeExpectancy  142 non-null    float64
#  4   population      142 non-null    int64
#  5   gdpPerCapita    142 non-null    float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 7.8+ KB

# %%
x=range(10)
plt.figure(figsize=(12,6))
top_10_p=data_2007.sort_values('population', ascending=False). head(10)
plt.xticks(x, top_10_p['country'])
plt.bar(x, top_10_p['population']/10**9)
plt.xlabel('Countries')
plt.ylabel('Population in Billions')
plt.title('Ten Most Populated Countries in 2007')
plt.show()

# %% [markdown]
# ## 8 Scatter Plot
# * Scatter plot helps in visualizing 2 numeric variables.
# * It helps in identifying the relationship of the data with each variable i.e correlation or trend patterns.
# * It also helps in detecting outliers in the plot.
# * It is used in Machine learning concepts like regression, where x and y are continuous variables. It is also used in clustering scatters or outlier detection.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.scatter(data_2007['gdpPerCapita'], data_2007['lifeExpectancy'])
plt.xlabel('GDP per Capita ($)')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy vs GDP per capita in the year 2007')
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

countries=pd.read_csv('countries.csv')

# %%
countries.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
countries['gdpPerCapita'].corr(countries['lifeExpectancy'])
# Out:
# 0.5837062198659806

# %%
countries['gdpPerCapita'].corr(countries['lifeExpectancy'])
# Out:
# 0.5837062198659806

# %%
countries['population'].corr(countries['year'])
# Out:
# 0.08230807783830925

# %%
countries['continent'].value_counts()
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64

# %%
# Histogram
plt.hist(countries['continent'])
plt.title('Data distribution-Continent')
plt.xlabel('Continents')
# Out:
# Text(0.5, 0, 'Continents')

# %%
countries.describe()
# Out:
#              year  lifeExpectancy    population   gdpPerCapita
# count  1704.00000     1704.000000  1.704000e+03    1704.000000
# mean   1979.50000       59.474439  2.960121e+07    7215.327081
# std      17.26533       12.917107  1.061579e+08    9857.454543
# min    1952.00000       23.599000  6.001100e+04     241.165876
# 25%    1965.75000       48.198000  2.793664e+06    1202.060309
# 50%    1979.50000       60.712500  7.023596e+06    3531.846988
# 75%    1993.25000       70.845500  1.958522e+07    9325.462346
# max    2007.00000       82.603000  1.318683e+09  113523.132900

# %%
data_Africa=countries.loc[countries['continent']=='Africa']

# %%
data_Asia=countries.loc[countries['continent']=='Asia']
data_Europe=countries.loc[countries['continent']=='Europe']
data_Americas=countries.loc[countries['continent']=='Americas']
data_Oceania=countries.loc[countries['continent']=='Oceania']

# %%
#box plot

fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(nrows=1,ncols=5, figsize= (16,3))
ax1.boxplot(data_Africa['lifeExpectancy'], 
                 patch_artist=True,
                 notch=True,
                )
ax1.set_title('Africa')
ax2.boxplot(data_Asia['lifeExpectancy'], 
                 patch_artist=True,
                 notch=True)
ax2.set_title('Asia')
ax3.boxplot(data_Europe['lifeExpectancy'], 
                 patch_artist=True,
                 notch=True)
ax3.set_title('Europe')
ax4.boxplot(data_Americas['lifeExpectancy'], 
                 patch_artist=True,
                 notch=True)
ax4.set_title('Americas')
ax5.boxplot(data_Oceania['lifeExpectancy'], 
                 patch_artist=True,
                 notch=True)
ax5.set_title('Oceania')

plt.show()

# %%
fig.savefig('continent_lifeexpectancy.png')
